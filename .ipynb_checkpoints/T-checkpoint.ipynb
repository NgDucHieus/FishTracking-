# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Input folder containing CSV files
input_folder = r"C:\Users\MAY02\Desktop\FishTracking-\Data\FeMe-MaMos-MaMe"
# Output folder to save the plots
output_folder = r"C:\Users\MAY02\Desktop\FishTracking-\FeMe-MaMos-MaMe-histogram"

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Part labels
labels = ['FeMe', 'MaMos', 'MaMe']

# Dictionaries to store mean distances by part
mean_distances = {label: [] for label in labels}

# Loop through all CSV files in the input folder
for file_name in os.listdir(input_folder):
    if file_name.endswith(".csv"):  # Process only CSV files
        # Full path to the current CSV file
        file_path = os.path.join(input_folder, file_name)

        # Extract file name without the extension
        clean_file_name = os.path.splitext(file_name)[0]

        try:
            # Read the CSV file
            df = pd.read_csv(file_path)

            # Group by 'part' and calculate mean 'total_distance'
            total_distance_by_part = df.groupby('part')['total_distance'].mean().reset_index()
            print(f"File: {file_name}, Grouped Data:\n{total_distance_by_part}")  # Debugging print

            # Store the mean distances for each part
            for label in labels:
                mean_value = total_distance_by_part.loc[
                    total_distance_by_part['part'] == label, 'total_distance'
                ]
                # Append the mean value or 0 if the part is missing
                value_to_append = mean_value.values[0] if not mean_value.empty else 0
                print(f"Part: {label}, Value to append: {value_to_append}")  # Debugging print
                mean_distances[label].append(value_to_append)

            # Plotting
            plt.figure(figsize=(10, 6))
            plt.bar(labels, total_distance_by_part.set_index('part').reindex(labels, fill_value=0)['total_distance'], color='skyblue')
            plt.ylabel('Total Distance')
            plt.title(clean_file_name)  # Set title dynamically based on file name
            plt.xticks(rotation=45)
            plt.grid(axis='y')
            plt.tight_layout()

            # Save the plot to the output folder
            output_file_path = os.path.join(output_folder, f"{clean_file_name}_total_distance_barplot.png")
            plt.savefig(output_file_path, dpi=300)
            plt.close()  # Close the plot to free memory
            print(f"Plot saved for: {file_name} -> {output_file_path}")

        except Exception as e:
            print(f"Error processing {file_name}: {e}")

# Print the collected mean distances for each part
for part, distances in mean_distances.items():
    print(f"{part} = {distances}")

print("Processing complete. All bar plots saved and mean distances collected.")
# Out:
# File: FeMe-MaMos-MaMe-d0-0ng_tracking_data.csv, Grouped Data:
#    part  total_distance
# 0     0        0.292430
# 1     1        0.267957
# 2     2        0.813128
# Part: FeMe, Value to append: 0
# Part: MaMos, Value to append: 0
# Part: MaMe, Value to append: 0
# Plot saved for: FeMe-MaMos-MaMe-d0-0ng_tracking_data.csv -> C:\Users\MAY02\Desktop\FishTracking-\FeMe-MaMos-MaMe-histogram\FeMe-MaMos-MaMe-d0-0ng_tracking_data_total_distance_barplot.png
# File: FeMe-MaMos-MaMe-d2-25ng_tracking_data.csv, Grouped Data:
#    part  total_distance
# 0     0        0.123420
# 1     1        0.280238
# 2     2        0.126067
# Part: FeMe, Value to append: 0
# Part: MaMos, Value to append: 0
# Part: MaMe, Value to append: 0
# Plot saved for: FeMe-MaMos-MaMe-d2-25ng_tracking_data.csv -> C:\Users\MAY02\Desktop\FishTracking-\FeMe-MaMos-MaMe-histogram\FeMe-MaMos-MaMe-d2-25ng_tracking_data_total_distance_barplot.png
# File: FeMe-MaMos-MaMe-d2-5ng_tracking_data.csv, Grouped Data:
#    part  total_distance
# 0     0        0.279120
# 1     1        0.279293
# 2     2        0.194377
# Part: FeMe, Value to append: 0
# Part: MaMos, Value to append: 0
# Part: MaMe, Value to append: 0
# Plot saved for: FeMe-MaMos-MaMe-d2-5ng_tracking_data.csv -> C:\Users\MAY02\Desktop\FishTracking-\FeMe-MaMos-MaMe-histogram\FeMe-MaMos-MaMe-d2-5ng_tracking_data_total_distance_barplot.png
# File: FeMe-MaMos-MaMe-d4-5ng_tracking_data.csv, Grouped Data:
#    part  total_distance
# 0     0        0.143575
# 1     1        0.272086
# 2     2        0.214312
# Part: FeMe, Value to append: 0
# Part: MaMos, Value to append: 0
# Part: MaMe, Value to append: 0
# Plot saved for: FeMe-MaMos-MaMe-d4-5ng_tracking_data.csv -> C:\Users\MAY02\Desktop\FishTracking-\FeMe-MaMos-MaMe-histogram\FeMe-MaMos-MaMe-d4-5ng_tracking_data_total_distance_barplot.png
# File: FeMe-MaMos-MaMe-d7-5ng_tracking_data.csv, Grouped Data:
#    part  total_distance
# 0     0        0.171028
# 1     1        0.237335
# 2     2        0.142259
# Part: FeMe, Value to append: 0
# Part: MaMos, Value to append: 0
# Part: MaMe, Value to append: 0
# Plot saved for: FeMe-MaMos-MaMe-d7-5ng_tracking_data.csv -> C:\Users\MAY02\Desktop\FishTracking-\FeMe-MaMos-MaMe-histogram\FeMe-MaMos-MaMe-d7-5ng_tracking_data_total_distance_barplot.png
# File: FeMe-MaMos-MaMe-Rev-5ng_tracking_data.csv, Grouped Data:
#    part  total_distance
# 0     0        0.163233
# 1     1        0.185158
# 2     2        0.203954
# Part: FeMe, Value to append: 0
# Part: MaMos, Value to append: 0
# Part: MaMe, Value to append: 0
# Plot saved for: FeMe-MaMos-MaMe-Rev-5ng_tracking_data.csv -> C:\Users\MAY02\Desktop\FishTracking-\FeMe-MaMos-MaMe-histogram\FeMe-MaMos-MaMe-Rev-5ng_tracking_data_total_distance_barplot.png
# FeMe = [0, 0, 0, 0, 0, 0]
# MaMos = [0, 0, 0, 0, 0, 0]
# MaMe = [0, 0, 0, 0, 0, 0]
# Processing complete. All bar plots saved and mean distances collected.

# %%
import matplotlib.pyplot as plt

# Data
FeMe = [0.292429742624545, 0.12341966164416969, 0.2791198889469528, 0.14357529661368112, 0.1710282562995867, 0.16323265133330514]
MaMos = [0.2679569988739745, 0.28023756937447136, 0.27929279971736487, 0.2720856301946432, 0.23733541007939693, 0.18515793177148646]
MaMe = [0.81312846778974, 0.12606730017478682, 0.19437678959892837, 0.21431240922183722, 0.1422586106810511, 0.2039538370677772]
Time = ['d0-0ng', 'd2-25ng', 'd2-5ng', 'd4-5ng', 'd7-5ng', 'Rev-5ng']

# Plot
plt.figure(figsize=(10, 6))
plt.plot(Time, FeMe, label='FeMe', marker='o')
plt.plot(Time, MaMos, label='MaMos', marker='s')
plt.plot(Time, MaMe, label='MaMe', marker='^')

# Labels and Title
plt.xlabel('Time')
plt.ylabel('Mean Total Distance')
plt.title('Mean Total Distance Over Time')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd

# Input folder containing CSV files
input_folder = r"C:\Users\MAY02\Desktop\FishTracking-\Data\MaMe-FeMos-FeMe"

# Initialize dictionaries to store average velocities
average_velocities = {0: [], 1: [], 2: []}  # 0 -> FeMe, 1 -> MaMos, 2 -> MaMe
time_points = []

# Process each file in the folder
for file_name in os.listdir(input_folder):
    if file_name.endswith('.csv'):
        # Full path to the file
        file_path = os.path.join(input_folder, file_name)
        
        # Extract the time label from the file name
        time_label = file_name.replace('_tracking_data.csv', '')
        time_points.append(time_label)
        
        # Read the CSV file
        df = pd.read_csv(file_path)
        
        # Group by 'part' and calculate mean 'average_velocity_by_part'
        grouped = df.groupby('part')['average_velocity_by_part'].mean()
        
        # Append the results to the corresponding lists
        for part in average_velocities.keys():
            average_velocities[part].append(grouped.get(part, 0))  # Default to 0 if part is missing

# Convert parts to labels for readability
labels = {0: 'FeMe', 1: 'MaMos', 2: 'MaMe'}
average_velocities_named = {labels[key]: values for key, values in average_velocities.items()}

# Display the collected average velocities for each part
print("Collected Average Velocities by Part:")
for part, velocities in average_velocities_named.items():
    print(f"{part}: {velocities}")

# Save results to a CSV file
output_file = os.path.join(input_folder, "average_velocities_summary.csv")
result_df = pd.DataFrame(average_velocities_named, index=time_points)
result_df.index.name = "Time"
result_df.to_csv(output_file)

print(f"\nSummary saved to: {output_file}")
# Out:
# Collected Average Velocities by Part:
# FeMe: [0.404971149029692, 0.5137906179104504, 0.43526493737217903, 0.456228171504162, 0.3242325792640491]
# MaMos: [0.5569075017648862, 0.5074266057020352, 0.5885575030757783, 0.4763049712130347, 0.4525407844213348]
# MaMe: [0.5548855308804376, 0.4880200571544823, 0.5511778755062122, 0.3938628634790321, 0.42250598005677337]
#
# Summary saved to: C:\Users\MAY02\Desktop\FishTracking-\Data\MaMe-FeMos-FeMe\average_velocities_summary.csv

# %%
import matplotlib.pyplot as plt

# Data
FeMe = [0.3804431038655152, 0.7448662072437466, 0.5283538430378948, 0.4606032813647054, 0.53071845009572, 0.3 100.47630497121303478862,[0.4180250325938298, 0.609985676634943, 10.47630497121303475, 0.4800511273053549, 0.6191344990308023, 0.505077477710388]
MaMe = [0.2993674564081986, 0.4799312948012777, 0.4527102414342644, 0.4289020075906892, 0.5219834673316732, 0.4422603819568516]MaMos
Time = ['d0-0ng', 'd2-25ng', 'd2-5ng', 'd4-5ng', 'd7-5ng',]

# Plot
plt.figure(figsize=(10, 6))
plt.plot(Time, FeMe, label='FeMe', marker='o')
plt.plot(Time, MaMos, label='MaMos', marker='s')
plt.plot(Time, MaMe, label='MaMe', marker='^')

# Labels and Title
plt.xlabel('Time')
plt.ylabel('Average velocity (m/s)')
plt.title('Average velocity Over Time FeMe-MaMos-MaMe')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.savefig("FeMe-MaMos-MaMe-Average velocity.png")

plt.show()
